# %% [markdown]
# # Demo: Temporal network visualisation in `pathpy 2.0`

# %%
import pathpy as pp
import sqlite3

# %% [markdown]
# Thanks to pathpy's SQLite support, we can directly load temporal networks from a database file. We first connect to the database and set the row factory.

# %%
con = sqlite3.connect('../../data/temporal_networks.db')
con.row_factory = sqlite3.Row
tempnet = pp.TemporalNetwork.fromSQLite(con.execute('SELECT source, target, time FROM lotr'), directed=False)
# Out:
# 2018-02-26 18:45:45 [Severity.INFO]	Retrieving undirected time-stamped links ...
# 2018-02-26 18:45:45 [Severity.INFO]	Building index data structures ...
# 2018-02-26 18:45:45 [Severity.INFO]	Sorting time stamps ...
# 2018-02-26 18:45:45 [Severity.INFO]	finished.

# %% [markdown]
# Creating an interactive visualisation is as simple as:

# %%
tempnet
# Out:
# <style>
#     .tlinks line {
#     stroke: rgb(209, 208, 208);
#     stroke-opacity: 0.2;
#     }
#     .tlinks line.active {
#     stroke: #922;
#     stroke-opacity: 1;
#     stroke-width: 4px;
#     }
#     .tnodes circle {
#     stroke: #222;
#     fill: #eee;
#     fill-opacity: 1;
#     stroke-width: 1.5px;
#     }
#     .tnodes circle.active {
#     stroke: #222;
#     fill: #922;
#     fill-opacity: 1;
#     stroke-width: 1.5px;
#     }
# </style>
#
# <svg width="600" height="600" id="vVYbERMr">
#     <text x="10" y="20" font-family="sans-serif" font-size="14px" fill="red"
#         id='vVYbERMr_time_txt'>t = 0</text>
#     <text x="120" y="20" font-family="sans-serif" font-size="14px" fill="blue" style="cursor: pointer"
#         id='vVYbERMr_start_txt'>stop</text>
#     <text x="170" y="20" font-family="sans-serif" font-size="14px" fill="blue" style="cursor: pointer"
#         id='vVYbERMr_restart_txt'>restart</text>
# </svg>
# <script charset="utf-8">
# require.config({
#     paths: {
#         d3: "https://d3js.org/d3.v4.min"
#     }
# });
# require(["d3"], function(d3) {
#     d3.selection.prototype.moveToFront = function() {
#         return this.each(function(){
#             this.parentNode.appendChild(this);
#         });
#     };
#
#     d3.selection.prototype.moveToBack = function() {
#         return this.each(function() {
#             var firstChild = this.parentNode.firstChild;
#             if (firstChild) {
#                 this.parentNode.insertBefore(this, firstChild);
#             }
#         });
#     };
#
#     var svg = d3.select("#vVYbERMr"),
#         width = +svg.attr("width"),
#         height = +svg.attr("height"),
#         radius = 6,
#         color = d3.scaleOrdinal(d3.schemeCategory20b);
#
#     var temporal_net = {"nodes": [{"group": 1, "id": "\u00d3in"}, {"group": 1, "id": "Thr\u00f3r"}, {"group": 1, "id": "F\u00ebanor"}, {"group": 1, "id": "Erkenbrand"}, {"group": 1, "id": "Odo"}, {"group": 1, "id": "Arvedui"}, {"group": 1, "id": "\u00c9owyn"}, {"group": 1, "id": "Glorfindel"}, {"group": 1, "id": "Galdor"}, {"group": 1, "id": "Angbor"}, {"group": 1, "id": "Fastred"}, {"group": 1, "id": "Gollum"}, {"group": 1, "id": "Folcwine"}, {"group": 1, "id": "Aragorn"}, {"group": 1, "id": "Ungoliant"}, {"group": 1, "id": "Fredegar"}, {"group": 1, "id": "Samwise"}, {"group": 1, "id": "Ohtar"}, {"group": 1, "id": "Daeron"}, {"group": 1, "id": "E\u00e4rendil"}, {"group": 1, "id": "Faramir"}, {"group": 1, "id": "Blanco"}, {"group": 1, "id": "Bill"}, {"group": 1, "id": "Barahir"}, {"group": 1, "id": "Fengel"}, {"group": 1, "id": "Galadriel"}, {"group": 1, "id": "Bergil"}, {"group": 1, "id": "Baldor"}, {"group": 1, "id": "Meriadoc"}, {"group": 1, "id": "Elwing"}, {"group": 1, "id": "Merry"}, {"group": 1, "id": "Gl\u00f3in"}, {"group": 1, "id": "Lotho"}, {"group": 1, "id": "Sm\u00e9agol"}, {"group": 1, "id": "D\u00fanhere"}, {"group": 1, "id": "C\u00edrdan"}, {"group": 1, "id": "Pippin"}, {"group": 1, "id": "Bob"}, {"group": 1, "id": "Fr\u00e9a"}, {"group": 1, "id": "Gil_galad"}, {"group": 1, "id": "Treebeard"}, {"group": 1, "id": "Nimloth"}, {"group": 1, "id": "Legolas"}, {"group": 1, "id": "E\u00e4rnur"}, {"group": 1, "id": "Isildur"}, {"group": 1, "id": "Walda"}, {"group": 1, "id": "Th\u00e9oden"}, {"group": 1, "id": "H\u00farin"}, {"group": 1, "id": "Beorn"}, {"group": 1, "id": "Nob"}, {"group": 1, "id": "Smaug"}, {"group": 1, "id": "Elendil"}, {"group": 1, "id": "Ori"}, {"group": 1, "id": "Harding"}, {"group": 1, "id": "Bofur"}, {"group": 1, "id": "Shadowfax"}, {"group": 1, "id": "Brand"}, {"group": 1, "id": "Radagast"}, {"group": 1, "id": "Gh\u00e2n_buri_Gh\u00e2n"}, {"group": 1, "id": "Shagrat"}, {"group": 1, "id": "Beregond"}, {"group": 1, "id": "Erestor"}, {"group": 1, "id": "Frodo"}, {"group": 1, "id": "Robin"}, {"group": 1, "id": "Marcho"}, {"group": 1, "id": "Goldberry"}, {"group": 1, "id": "R\u00famil"}, {"group": 1, "id": "Bain"}, {"group": 1, "id": "Horn"}, {"group": 1, "id": "Finduilas"}, {"group": 1, "id": "Dwalin"}, {"group": 1, "id": "Grimbeorn"}, {"group": 1, "id": "Celebrimbor"}, {"group": 1, "id": "Goldilocks"}, {"group": 1, "id": "Boromir"}, {"group": 1, "id": "Helm"}, {"group": 1, "id": "Hirgon"}, {"group": 1, "id": "Gram"}, {"group": 1, "id": "Celebr\u00edan"}, {"group": 1, "id": "Aldor"}, {"group": 1, "id": "L\u00fathien"}, {"group": 1, "id": "Elessar"}, {"group": 1, "id": "Sauron"}, {"group": 1, "id": "Maggot"}, {"group": 1, "id": "Arwen"}, {"group": 1, "id": "Bard"}, {"group": 1, "id": "Tom"}, {"group": 1, "id": "Meneldil"}, {"group": 1, "id": "Elrond"}, {"group": 1, "id": "Balin"}, {"group": 1, "id": "D\u00e9agol"}, {"group": 1, "id": "Peregrin"}, {"group": 1, "id": "Gamling"}, {"group": 1, "id": "Grimbold"}, {"group": 1, "id": "Halfast"}, {"group": 1, "id": "Halbarad"}, {"group": 1, "id": "Hamfast"}, {"group": 1, "id": "Bombur"}, {"group": 1, "id": "Butterbur"}, {"group": 1, "id": "T\u00farin"}, {"group": 1, "id": "\u00c9omer"}, {"group": 1, "id": "D\u00e9or"}, {"group": 1, "id": "Celeborn"}, {"group": 1, "id": "An\u00e1rion"}, {"group": 1, "id": "Barliman"}, {"group": 1, "id": "Gandalf"}, {"group": 1, "id": "Thingol"}, {"group": 1, "id": "Imrahil"}, {"group": 1, "id": "Meneldor"}, {"group": 1, "id": "Shelob"}, {"group": 1, "id": "Brego"}, {"group": 1, "id": "Gimli"}, {"group": 1, "id": "Hador"}, {"group": 1, "id": "Forlong"}, {"group": 1, "id": "Folca"}, {"group": 1, "id": "Goldwine"}, {"group": 1, "id": "Ecthelion"}, {"group": 1, "id": "Thranduil"}, {"group": 1, "id": "Saruman"}, {"group": 1, "id": "Valandil"}, {"group": 1, "id": "Anborn"}, {"group": 1, "id": "Bilbo"}, {"group": 1, "id": "Thengel"}, {"group": 1, "id": "Sam"}, {"group": 1, "id": "Orophin"}, {"group": 1, "id": "Haldir"}, {"group": 1, ...

# %% [markdown]
# Using the method introduced in
#
# - I Scholtes: When is a Network a Network? Multi-Order Graphical Model Selection in Pathways and Temporal Networks. In KDD'17  - Proceedings of the 23rd ACM SIGKDD International Conference on Knowledge Discovery and Data Mining, 2017
#
# we can learn a multi-order graphical model for the causal path structure in this temporal network as follows:

# %%
p = pp.PathExtraction.TemporalPaths.extract(tempnet, delta=30)
m = pp.MultiOrderModel(p, maxOrder=2)
# Out:
# 2018-02-26 18:45:45 [Severity.INFO]	Extracting time-respecting paths for delta = 30 ...
# 2018-02-26 18:45:45 [Severity.INFO]	Calculating sub path statistics ...
# 2018-02-26 18:45:45 [Severity.INFO]	finished.
# 2018-02-26 18:45:45 [Severity.INFO]	Generating 0-th order network layer ...
# 2018-02-26 18:45:45 [Severity.INFO]	Generating 1-th order network layer ...
# 2018-02-26 18:45:45 [Severity.INFO]	Generating 2-th order network layer ...
# 2018-02-26 18:45:45 [Severity.INFO]	finished.

# %% [markdown]
# We can visualise the (first-order) time-aggregated network as follows:

# %%
m.layers[1]
# Out:
# <style>
#     .links line {
#     stroke: #999;
#     stroke-opacity: 0.6;
#     }
#     .nodes circle {
#     stroke: #fff;
#     stroke-width: 1.5px;
#     }
# </style>
#
# <svg width="600" height="600" id="QhB3u2WL"></svg>
#
# <script charset="utf-8">
# require.config({
#     paths: {
#         d3: "https://d3js.org/d3.v4.min"
#     }
# });
# require(["d3"], function(d3) {
#
#     var svg = d3.select("#"+"QhB3u2WL"),
#         radius = 6,
#         width = +svg.attr("width"),
#         height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"nodes": [{"group": 1, "id": "Aldor"}, {"group": 1, "id": "Amroth"}, {"group": 1, "id": "Anborn"}, {"group": 1, "id": "Angbor"}, {"group": 1, "id": "An\u00e1rion"}, {"group": 1, "id": "Aragorn"}, {"group": 1, "id": "Arvedui"}, {"group": 1, "id": "Arwen"}, {"group": 1, "id": "Bain"}, {"group": 1, "id": "Baldor"}, {"group": 1, "id": "Balin"}, {"group": 1, "id": "Barahir"}, {"group": 1, "id": "Bard"}, {"group": 1, "id": "Barliman"}, {"group": 1, "id": "Beorn"}, {"group": 1, "id": "Beregond"}, {"group": 1, "id": "Beren"}, {"group": 1, "id": "Bergil"}, {"group": 1, "id": "Bilbo"}, {"group": 1, "id": "Bill"}, {"group": 1, "id": "Blanco"}, {"group": 1, "id": "Bob"}, {"group": 1, "id": "Bofur"}, {"group": 1, "id": "Bombur"}, {"group": 1, "id": "Boromir"}, {"group": 1, "id": "Brand"}, {"group": 1, "id": "Brego"}, {"group": 1, "id": "Butterbur"}, {"group": 1, "id": "Celeborn"}, {"group": 1, "id": "Celebrimbor"}, {"group": 1, "id": "Celebr\u00edan"}, {"group": 1, "id": "C\u00edrdan"}, {"group": 1, "id": "Daeron"}, {"group": 1, "id": "Damrod"}, {"group": 1, "id": "Dior"}, {"group": 1, "id": "Dwalin"}, {"group": 1, "id": "D\u00e9agol"}, {"group": 1, "id": "D\u00e9or"}, {"group": 1, "id": "D\u00fanhere"}, {"group": 1, "id": "Ecthelion"}, {"group": 1, "id": "Elendil"}, {"group": 1, "id": "Elessar"}, {"group": 1, "id": "Elrond"}, {"group": 1, "id": "Elwing"}, {"group": 1, "id": "Erestor"}, {"group": 1, "id": "Erkenbrand"}, {"group": 1, "id": "E\u00e4rendil"}, {"group": 1, "id": "E\u00e4rnur"}, {"group": 1, "id": "Faramir"}, {"group": 1, "id": "Fastred"}, {"group": 1, "id": "Fengel"}, {"group": 1, "id": "Findegil"}, {"group": 1, "id": "Finduilas"}, {"group": 1, "id": "Folca"}, {"group": 1, "id": "Folcwine"}, {"group": 1, "id": "Forlong"}, {"group": 1, "id": "Fredegar"}, {"group": 1, "id": "Frodo"}, {"group": 1, "id": "Fr\u00e9a"}, {"group": 1, "id": "Fundin"}, {"group": 1, "id": "F\u00ebanor"}, {"group": 1, "id": "Galadriel"}, {"group": 1, "id": "Galdor"}, {"group": 1, "id": "Gamling"}, {"group": 1, "id": "Gandalf"}, {"group": 1, "id": "Gh\u00e2n-buri-Gh\u00e2n"}, {"group": 1, "id": "Gil-galad"}, {"group": 1, "id": "Gimli"}, {"group": 1, "id": "Glorfindel"}, {"group": 1, "id": "Gl\u00f3in"}, {"group": 1, "id": "Goldberry"}, {"group": 1, "id": "Goldilocks"}, {"group": 1, "id": "Goldwine"}, {"group": 1, "id": "Gollum"}, {"group": 1, "id": "Gorbag"}, {"group": 1, "id": "Gram"}, {"group": 1, "id": "Grimbeorn"}, {"group": 1, "id": "Grimbold"}, {"group": 1, "id": "Hador"}, {"group": 1, "id": "Halbarad"}, {"group": 1, "id": "Haldir"}, {"group": 1, "id": "Halfast"}, {"group": 1, "id": "Hamfast"}, {"group": 1, "id": "Harding"}, {"group": 1, "id": "Helm"}, {"group": 1, "id": "Hirgon"}, {"group": 1, "id": "Horn"}, {"group": 1, "id": "H\u00farin"}, {"group": 1, "id": "Imrahil"}, {"group": 1, "id": "Isildur"}, {"group": 1, "id": "Legolas"}, {"group": 1, "id": "Lobelia"}, {"group": 1, "id": "Lotho"}, {"group": 1, "id": "L\u00fathien"}, {"group": 1, "id": "Mablung"}, {"group": 1, "id": "Maggot"}, {"group": 1, "id": "Marcho"}, {"group": 1, "id": "Meneldil"}, {"group": 1, "id": "Meneldor"}, {"group": 1, "id": "Meriadoc"}, {"group": 1, "id": "Merry"}, {"group": 1, "id": "Nimloth"}, {"group": 1, "id": "Nob"}, {"group": 1, "id": "Odo"}, {"group": 1, "id": "Ohtar"}, {"group": 1, "id": "Ori"}, {"group": 1, "id": "Orophin"}, {"group": 1, "id": "Peregrin"}, {"group": 1, "id": "Pippin"}, {"group": 1, "id": "Radagast"}, {"group": 1, "id": "Robin"}, {"group": 1, "id": "R\u00famil"}, {"group": 1, "id": "Sam"}, {"group": 1, "id": "Samwise"}, {"group": 1, "id": "Saruman"}, {"group": 1, "id": "Sauron"}, {"group": 1, "id": "Shadowfax"}, {"group": 1, "id": "Shagrat"}, {"group": 1, "id": "Shelob"}, {"group": 1, "id": "Smaug"}, {"group": 1, "id": "Sm\u00e9agol"}, {"group": 1, "id": "Thengel"}, {"group": 1, "id": "Thingol"}, {"group": 1, "id": "Thorin"}, {"group": 1, "id": "Thranduil"}, {"group": 1, "id": "Thr\u00f3r"}, {"group": 1, "id": "Th\u00e9oden"}, {"grou ...

# %% [markdown]
# Visualising higher-order layers of the model is as easy as ...

# %%
m.layers[2]
# Out:
# <style>
#     .links line {
#     stroke: #999;
#     stroke-opacity: 0.6;
#     }
#     .nodes circle {
#     stroke: #fff;
#     stroke-width: 1.5px;
#     }
# </style>
#
# <svg width="600" height="600" id="jsZT7ZB8"></svg>
#
# <script charset="utf-8">
# require.config({
#     paths: {
#         d3: "https://d3js.org/d3.v4.min"
#     }
# });
# require(["d3"], function(d3) {
#
#     var svg = d3.select("#"+"jsZT7ZB8"),
#         radius = 6,
#         width = +svg.attr("width"),
#         height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"nodes": [{"group": 1, "id": "Aldor,Th\u00e9oden"}, {"group": 1, "id": "Amroth,Aragorn"}, {"group": 1, "id": "Amroth,Arwen"}, {"group": 1, "id": "Amroth,Elrond"}, {"group": 1, "id": "Amroth,Faramir"}, {"group": 1, "id": "Amroth,Frodo"}, {"group": 1, "id": "Amroth,Gandalf"}, {"group": 1, "id": "Amroth,Gimli"}, {"group": 1, "id": "Amroth,Imrahil"}, {"group": 1, "id": "Amroth,Pippin"}, {"group": 1, "id": "Amroth,\u00c9omer"}, {"group": 1, "id": "Amroth,\u00c9owyn"}, {"group": 1, "id": "Anborn,Frodo"}, {"group": 1, "id": "An\u00e1rion,Elendil"}, {"group": 1, "id": "An\u00e1rion,Isildur"}, {"group": 1, "id": "An\u00e1rion,Meneldil"}, {"group": 1, "id": "Aragorn,Arvedui"}, {"group": 1, "id": "Aragorn,Arwen"}, {"group": 1, "id": "Aragorn,Beregond"}, {"group": 1, "id": "Aragorn,Boromir"}, {"group": 1, "id": "Aragorn,Celeborn"}, {"group": 1, "id": "Aragorn,Elendil"}, {"group": 1, "id": "Aragorn,Elessar"}, {"group": 1, "id": "Aragorn,Elrond"}, {"group": 1, "id": "Aragorn,Faramir"}, {"group": 1, "id": "Aragorn,Frodo"}, {"group": 1, "id": "Aragorn,Galadriel"}, {"group": 1, "id": "Aragorn,Gandalf"}, {"group": 1, "id": "Aragorn,Gimli"}, {"group": 1, "id": "Aragorn,Gollum"}, {"group": 1, "id": "Aragorn,Halbarad"}, {"group": 1, "id": "Aragorn,Haldir"}, {"group": 1, "id": "Aragorn,Imrahil"}, {"group": 1, "id": "Aragorn,Isildur"}, {"group": 1, "id": "Aragorn,Legolas"}, {"group": 1, "id": "Aragorn,Meriadoc"}, {"group": 1, "id": "Aragorn,Merry"}, {"group": 1, "id": "Aragorn,Nimloth"}, {"group": 1, "id": "Aragorn,Pippin"}, {"group": 1, "id": "Aragorn,Sam"}, {"group": 1, "id": "Aragorn,Saruman"}, {"group": 1, "id": "Aragorn,Sauron"}, {"group": 1, "id": "Aragorn,Shadowfax"}, {"group": 1, "id": "Aragorn,Th\u00e9oden"}, {"group": 1, "id": "Aragorn,Treebeard"}, {"group": 1, "id": "Aragorn,\u00c9omer"}, {"group": 1, "id": "Aragorn,\u00c9owyn"}, {"group": 1, "id": "Arvedui,Aragorn"}, {"group": 1, "id": "Arwen,Aragorn"}, {"group": 1, "id": "Arwen,Bilbo"}, {"group": 1, "id": "Arwen,Elessar"}, {"group": 1, "id": "Arwen,Elrond"}, {"group": 1, "id": "Arwen,Frodo"}, {"group": 1, "id": "Arwen,Imrahil"}, {"group": 1, "id": "Baldor,Brego"}, {"group": 1, "id": "Baldor,Th\u00e9oden"}, {"group": 1, "id": "Balin,Frodo"}, {"group": 1, "id": "Balin,Gimli"}, {"group": 1, "id": "Barahir,Beren"}, {"group": 1, "id": "Barahir,L\u00fathien"}, {"group": 1, "id": "Barahir,Thingol"}, {"group": 1, "id": "Beorn,Frodo"}, {"group": 1, "id": "Beregond,Bergil"}, {"group": 1, "id": "Beregond,Ecthelion"}, {"group": 1, "id": "Beregond,Faramir"}, {"group": 1, "id": "Beregond,Gandalf"}, {"group": 1, "id": "Beregond,Meriadoc"}, {"group": 1, "id": "Beregond,Peregrin"}, {"group": 1, "id": "Beregond,Pippin"}, {"group": 1, "id": "Beregond,Shadowfax"}, {"group": 1, "id": "Beren,Barahir"}, {"group": 1, "id": "Beren,Bilbo"}, {"group": 1, "id": "Beren,Frodo"}, {"group": 1, "id": "Beren,L\u00fathien"}, {"group": 1, "id": "Beren,Thingol"}, {"group": 1, "id": "Bergil,Forlong"}, {"group": 1, "id": "Bergil,Pippin"}, {"group": 1, "id": "Bilbo,Arwen"}, {"group": 1, "id": "Bilbo,Butterbur"}, {"group": 1, "id": "Bilbo,Elrond"}, {"group": 1, "id": "Bilbo,Frodo"}, {"group": 1, "id": "Bilbo,Gandalf"}, {"group": 1, "id": "Bilbo,Gollum"}, {"group": 1, "id": "Bilbo,Hamfast"}, {"group": 1, "id": "Bilbo,L\u00fathien"}, {"group": 1, "id": "Bilbo,Maggot"}, {"group": 1, "id": "Bilbo,Pippin"}, {"group": 1, "id": "Bilbo,Sam"}, {"group": 1, "id": "Bilbo,Tom"}, {"group": 1, "id": "Bill,Bob"}, {"group": 1, "id": "Bill,Frodo"}, {"group": 1, "id": "Bill,Gandalf"}, {"group": 1, "id": "Bill,Sam"}, {"group": 1, "id": "Bob,Bill"}, {"group": 1, "id": "Bob,Nob"}, {"group": 1, "id": "Bofur,Gl\u00f3in"}, {"group": 1, "id": "Bombur,Gl\u00f3in"}, {"group": 1, "id": "Boromir,Aragorn"}, {"group": 1, "id": "Boromir,Bilbo"}, {"group": 1, "id": "Boromir,Elendil"}, {"group": 1, "id": "Boromir,Elrond"}, {"group": 1, "id": "Boromir,Faramir"}, {"group": 1, "id": "Boromir,Frodo"}, {"group": 1, "id": "Boromir,Gandalf"}, {"group ...
