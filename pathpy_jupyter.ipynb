# %%
import pathpy as pp
import sqlite3

# %%
con = sqlite3.connect('../../data/temporal_networks.db')
con.row_factory = sqlite3.Row
tempnet = pp.TemporalNetwork.fromSQLite(con.execute('SELECT source, target, time FROM ants_1_1'), directed=False)
# Out:
# 2018-02-19 21:25:53 [Severity.INFO]	Retrieving undirected time-stamped links ...
# 2018-02-19 21:25:53 [Severity.INFO]	Building index data structures ...
# 2018-02-19 21:25:53 [Severity.INFO]	Sorting time stamps ...
# 2018-02-19 21:25:53 [Severity.INFO]	finished.

# %%
tempnet
# Out:
#         <style>
#         .tlinks line {
#         stroke: #fff;
#         stroke-opacity: 0.2;
#         }
#         .tlinks line.active {
#         stroke: #922;
#         stroke-opacity: 1;
#         stroke-width: 3px;
#         }
#         .tnodes circle {
#         stroke: #222;
#         fill: #eee;
#         fill-opacity: 1;
#         stroke-width: 1.5px;
#         }
#         .tnodes circle.active {
#         stroke: #222;
#         fill: #922;
#         fill-opacity: 1;
#         stroke-width: 1.5px;
#         }
#         </style>
#         <svg width="600" height="600" id="BxhHVmO6">
#             <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="red">time = 0</text>
#         </svg>
#
#
#     <script charset="utf-8">
#             require.config({
#                 paths: {
#                     d3: "https://d3js.org/d3.v4.min"
#                 }
#             });
#             require(["d3"], function(d3) {
#
#         d3.selection.prototype.moveToFront = function() {
#         return this.each(function(){
#         this.parentNode.appendChild(this);
#         });
#         };
#
#         d3.selection.prototype.moveToBack = function() {
#         return this.each(function() {
#             var firstChild = this.parentNode.firstChild;
#             if (firstChild) {
#                 this.parentNode.insertBefore(this, firstChild);
#             }
#         });
#         };
#
#         var svg = d3.select("#"+"BxhHVmO6"),
#             width = +svg.attr("width"),
#             height = +svg.attr("height"),
#             color = d3.scaleOrdinal(d3.schemeCategory20b);
#
#         var temporal_net = {"links": [{"time": 1093, "source": "GBGW", "value": 1, "target": "WBYG"}, {"time": 1093, "source": "WBYG", "value": 1, "target": "GBGW"}, {"time": 1104, "source": "GBGW", "value": 1, "target": "WBYG"}, {"time": 1104, "source": "WBYG", "value": 1, "target": "GBGW"}, {"time": 1121, "source": "GBGW", "value": 1, "target": "WBYG"}, {"time": 1121, "source": "WBYG", "value": 1, "target": "GBGW"}, {"time": 1161, "source": "GBGW", "value": 1, "target": "WBYG"}, {"time": 1161, "source": "WBYG", "value": 1, "target": "GBGW"}, {"time": 1214, "source": "GBGW", "value": 1, "target": "____pale"}, {"time": 1214, "source": "____pale", "value": 1, "target": "GBGW"}, {"time": 1232, "source": "GBGW", "value": 1, "target": "____pale"}, {"time": 1232, "source": "____pale", "value": 1, "target": "GBGW"}, {"time": 1247, "source": "GBGW", "value": 1, "target": "____pale"}, {"time": 1247, "source": "____pale", "value": 1, "target": "GBGW"}, {"time": 1294, "source": "GBGW", "value": 1, "target": "WBYG"}, {"time": 1294, "source": "WBYG", "value": 1, "target": "GBGW"}, {"time": 1329, "source": "GBGW", "value": 1, "target": "GR_Y2"}, {"time": 1329, "source": "GR_Y2", "value": 1, "target": "GBGW"}, {"time": 1415, "source": "GBGW", "value": 1, "target": "YGWW"}, {"time": 1415, "source": "YGWW", "value": 1, "target": "GBGW"}, {"time": 153, "source": "WBYG", "value": 1, "target": "YGWY"}, {"time": 153, "source": "YGWY", "value": 1, "target": "WBYG"}, {"time": 175, "source": "WBYG", "value": 1, "target": "YGWY"}, {"time": 175, "source": "YGWY", "value": 1, "target": "WBYG"}, {"time": 950, "source": "WBYG", "value": 1, "target": "YGWY"}, {"time": 950, "source": "YGWY", "value": 1, "target": "WBYG"}, {"time": 1008, "source": "WBYG", "value": 1, "target": "W___"}, {"time": 1008, "source": "W___", "value": 1, "target": "WBYG"}, {"time": 1028, "source": "WBYG", "value": 1, "target": "W___"}, {"time": 1028, "source": "W___", "value": 1, "target": "WBYG"}, {"time": 1090, "source": "WBYG", "value": 1, "target": "GBGW"}, {"time": 1090, "source": "GBGW", "value": 1, "target": "WBYG"}, {"time": 1103, "source": "WBYG", "value": 1, "target": "GBGW"}, {"time": 1103, "source": "GBGW", "value": 1, "target": "WBYG"}, {"time": 1127, "source": "WBYG", "value": 1, "target": "YGWY"}, {"time": 1127, "source": "YGWY", "value": 1, "target": "WBYG"}, {"time": 1141, "source": "WBYG", "value": 1, "target": "YYWR"}, {"time": 1141, "source": "YYWR", "value": 1, "target": "WBYG"}, {"time": 1160, "source": "WBYG", "value": 1, "target": "GBGW"}, {"time": 1160, "source": "GBGW", "value": 1, "target": "WBYG"}, {"time": 1170, "source": "WBYG", "value": 1, "target": "GBGW"}, {"time": 1170, "source": "GBGW", "value": 1, "target": "WBYG"}, {"time": 1238, "source": "WBYG", "value": 1, "target": "____pale"}, {"time": 1238, "source": "____pale", "value": 1, "target": "WBYG"}, {"time": 1267, "source": "WBYG", "value": 1, "target": "____pale"}, {"time": 1267, "source": "____pale", "value": 1, "target": "WBYG"}, {"time": 1310, "source": "WBYG", "value": 1, "target": "____pale"}, {"time": 1310, "source": "____pale", "value": 1, "target": "WBYG"}, {"time": 1320, "source": "WBYG", "value": 1, "target": "YYWR"}, {"time": 1320, "source": "YYWR", "value": 1, "target": "WBYG"}, {"time": 1357, "source": "WBYG", "value": 1, "target": "____pale"}, {"time": 1357, "source": "____pale", "value": 1, "target": "WBYG"}, {"time": 1408, "source": "WBYG", "value": 1, "target": "YGWW"}, {"time": 1408, "source": "YGWW", "value": 1, "target": "WBYG"}, {"time": 875, "source": "____bot", "value": 1, "target": "____corner"}, {"time": 875, "source": "____corner", "value": 1, "target": "____bot"}, {"time": 1051, "source": "____bot", "value": 1, "target": "_WYG"}, {"time": 1051, "source": "_WYG", "value": 1, "target": "____bot"}, {"time": 1111, "source": "____bot", "value": 1, "target": "GGRY"}, {"time": 1111, "source": "GGRY", "value": 1, "target": "____bot"}, {"time": 1164, "source": "____bot", "value ...

# %%
paths = pp.PathExtraction.TemporalPaths.extract(tempnet, delta=10)
network = pp.HigherOrderNetwork(paths)
# Out:
# 2018-02-19 21:25:53 [Severity.INFO]	Extracting time-respecting paths for delta = 10 ...
# 2018-02-19 21:25:53 [Severity.INFO]	Calculating sub path statistics ...
# 2018-02-19 21:25:53 [Severity.INFO]	finished.

# %%
network
# Out:
#         <style>
#         .links line {
#         stroke: #999;
#         stroke-opacity: 0.6;
#         }
#         .nodes circle {
#         stroke: #fff;
#         stroke-width: 1.5px;
#         }
#         </style>
#         <svg width="400" height="300" id="o2zr01rl"></svg>
#
#         <script charset="utf-8">
#         require.config({
#             paths: {
#                 d3: "https://d3js.org/d3.v4.min"
#             }
#         });
#         require(["d3"], function(d3) {
#
#             var svg = d3.select("#"+"o2zr01rl"),
#                 width = +svg.attr("width"),
#                 height = +svg.attr("height");
#
#             var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#             var graph = {"links": [{"source": "YY_R", "value": 1, "target": "YYY_"}, {"source": "GGW_", "value": 1, "target": "GBG_"}, {"source": "Y__W", "value": 1, "target": "WWBG"}, {"source": "WRWR", "value": 1, "target": "YYGGmid"}, {"source": "YYY_", "value": 1, "target": "YY_R"}, {"source": "GR_Y2", "value": 1, "target": "WRRY"}, {"source": "_W__", "value": 1, "target": "GR_Y"}, {"source": "GWRG", "value": 1, "target": "YYRB"}, {"source": "YYYY", "value": 1, "target": "WBGG"}, {"source": "_WWY", "value": 1, "target": "WBGG"}, {"source": "GR_Y", "value": 1, "target": "WG_R"}, {"source": "WBGW", "value": 1, "target": "_WGG"}, {"source": "GGW_", "value": 1, "target": "G___big"}, {"source": "GWRG", "value": 1, "target": "YWW_"}, {"source": "YWWW", "value": 1, "target": "_WYW"}, {"source": "GGRR", "value": 1, "target": "____bm"}, {"source": "_WYW", "value": 1, "target": "GGWY"}, {"source": "_R__", "value": 1, "target": "____bm"}, {"source": "GGRY", "value": 1, "target": "____pale"}, {"source": "_WYW", "value": 1, "target": "WRWR"}, {"source": "____pale", "value": 1, "target": "YYWR"}, {"source": "WRWR", "value": 1, "target": "_WWY"}, {"source": "G_W_", "value": 1, "target": "WYGG"}, {"source": "GG_W", "value": 1, "target": "GGWW"}, {"source": "____topleft", "value": 1, "target": "GGRR"}, {"source": "YYGGmid", "value": 1, "target": "YY_W"}, {"source": "WBGW", "value": 1, "target": "G_W_"}, {"source": "G_R_", "value": 1, "target": "WGWB"}, {"source": "____bot", "value": 1, "target": "YYWR"}, {"source": "YGWY", "value": 1, "target": "W___"}, {"source": "WGWB", "value": 1, "target": "WBGG"}, {"source": "GRYY", "value": 1, "target": "YYGG"}, {"source": "WGWB", "value": 1, "target": "WRBB"}, {"source": "GGRR", "value": 1, "target": "Y_WY"}, {"source": "G___big", "value": 1, "target": "_R__"}, {"source": "Y_WY", "value": 1, "target": "WG_R"}, {"source": "__W_", "value": 1, "target": "GRWG"}, {"source": "YY_R", "value": 1, "target": "YYRG"}, {"source": "G___", "value": 1, "target": "_WYW"}, {"source": "YGWW", "value": 1, "target": "GR__"}, {"source": "GGRR", "value": 1, "target": "WRR_"}, {"source": "____pale", "value": 1, "target": "_R__"}, {"source": "YYGGmid", "value": 1, "target": "WRWR"}, {"source": "WR__", "value": 1, "target": "GGWW"}, {"source": "GGWY", "value": 1, "target": "YYGG"}, {"source": "WBYG", "value": 1, "target": "W___"}, {"source": "YY_R", "value": 1, "target": "GRBR"}, {"source": "GYYY", "value": 1, "target": "____topleft"}, {"source": "GBG_", "value": 1, "target": "WBGG"}, {"source": "GR__", "value": 1, "target": "G_W_"}, {"source": "GGWW", "value": 1, "target": "Y___"}, {"source": "_W_Y", "value": 1, "target": "YY_R"}, {"source": "WGBB", "value": 1, "target": "____almost"}, {"source": "RWGY", "value": 1, "target": "GG_W"}, {"source": "YWWW", "value": 1, "target": "____corner"}, {"source": "WG_R", "value": 1, "target": "WRWR"}, {"source": "YGWW", "value": 1, "target": "_R__"}, {"source": "GGWY", "value": 1, "target": "G_W_"}, {"source": "G_R_", "value": 1, "target": "WG_R"}, {"source": "GGRR", "value": 1, "target": "WGGB"}, {"source": "YWW_", "value": 1, "target": "_WWY"}, {"source": "GG_W", "value": 1, "target": "WRRY"}, {"source": "GGGG", "value": 1, "target": "WYGG"}, {"source": "YYGGmid", "value": 1, "target": "WGGB"}, {"source": "GRWG", "value": 1, "target": "YYGG"}, {"source": "YWGW", "value": 1, "target": "YGWW"}, {"source": "____pale", "value": 1, "target": "YWWW"}, {"source": "GGWY", "value": 1, "target": "YYGGright"}, {"source": "WRR_", "value": 1, "target": "GRWG"}, {"source": "WG_R", "value": 1, "target": "____bm"}, {"source": "____pale", "value": 1, "target": "WGGB"}, {"source": "YYGG", "value": 1, "target": "____brood"}, {"source": "____pale", "value": 1, "target": "GBGW"}, {"source": "W___", "value": 1, "target": "GGRY"}, {"source": "RWGY", "value": 1, "target": "G_R_"}, {"source": "_WYW", "value": 1, "target": "G___"}, {"source": "WRBB", "value": 1, "target": "WYGG"}, {"source": "G_GW", "value": ...

# %%
t = pp.TemporalNetwork()
t.addEdge('a', 'b', 1)
t.addEdge('b', 'c', 2)
t.addEdge('c', 'd', 10)
t.addEdge('e', 'c', 15)
t.addEdge('c', 'a', 19)
t
# Out:
#         <style>
#         .tlinks line {
#         stroke: #fff;
#         stroke-opacity: 0.2;
#         }
#         .tlinks line.active {
#         stroke: #922;
#         stroke-opacity: 1;
#         stroke-width: 3px;
#         }
#         .tnodes circle {
#         stroke: #222;
#         fill: #eee;
#         fill-opacity: 1;
#         stroke-width: 1.5px;
#         }
#         .tnodes circle.active {
#         stroke: #222;
#         fill: #922;
#         fill-opacity: 1;
#         stroke-width: 1.5px;
#         }
#         </style>
#         <svg width="600" height="600" id="aHBMjHdo">
#             <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="red">time = 0</text>
#         </svg>
#
#
#     <script charset="utf-8">
#             require.config({
#                 paths: {
#                     d3: "https://d3js.org/d3.v4.min"
#                 }
#             });
#             require(["d3"], function(d3) {
#
#         d3.selection.prototype.moveToFront = function() {
#         return this.each(function(){
#         this.parentNode.appendChild(this);
#         });
#         };
#
#         d3.selection.prototype.moveToBack = function() {
#         return this.each(function() {
#             var firstChild = this.parentNode.firstChild;
#             if (firstChild) {
#                 this.parentNode.insertBefore(this, firstChild);
#             }
#         });
#         };
#
#         var svg = d3.select("#"+"aHBMjHdo"),
#             width = +svg.attr("width"),
#             height = +svg.attr("height"),
#             color = d3.scaleOrdinal(d3.schemeCategory20b);
#
#         var temporal_net = {"links": [{"time": 1, "source": "a", "value": 1, "target": "b"}, {"time": 2, "source": "b", "value": 1, "target": "c"}, {"time": 10, "source": "c", "value": 1, "target": "d"}, {"time": 15, "source": "e", "value": 1, "target": "c"}, {"time": 19, "source": "c", "value": 1, "target": "a"}], "nodes": [{"id": "a", "group": 1}, {"id": "b", "group": 1}, {"id": "c", "group": 1}, {"id": "d", "group": 1}, {"id": "e", "group": 1}]}
#
#         var edgesbytime = {};
#
#         // extract timestamps
#         time_stamps = temporal_net.links.map(link => link['time']);
#         time_stamps.forEach(function(t){
#                     edgesbytime[t] = [];
#                 });
#         links = [];
#         i = 0;
#
#         // extract static links
#         temporal_net.links.forEach(function(link){
#             console.log(link);
#             id = String(link.source + '-' + link.target);
#             edgesbytime[link.time].push(id);
#             l = { 'source': link.source, 'target': link.target, 'id': id };
#             if (!contains(links, l)){
#                 links.push(l);
#             }
#         });
#
#         mintime = d3.min(time_stamps);
#         maxtime = d3.max(time_stamps);
#
#         var simulation = d3.forceSimulation()
#             .force("link", d3.forceLink().id(function(d) { return d.id; }))
#             .force("charge", d3.forceManyBody())
#             .force("center", d3.forceCenter(width / 2, height / 2))
#             .alphaTarget(1)
#             .on("tick", ticked);
#
#         var link = svg.append("g")
#             .attr("class", "tlinks")
#             .selectAll("line")
#             .data(links)
#             .enter().append("line")
#             .attr("id", function(d) { return d.id; });
#
#         var node = svg.append("g")
#             .attr("class", "tnodes")
#             .selectAll("circle")
#             .data(temporal_net.nodes)
#             .enter().append("circle")
#             .attr('id', function(d) { return d.id; })
#             .attr("r", 5)
#             .call(d3.drag()
#                 .on("start", dragstarted)
#                 .on("drag", dragged)
#                 .on("end", dragended));
#
#         node.append("title")
#             .text(function(d) { return d.id; });
#
#         simulation.nodes(temporal_net.nodes)
#                         .on("tick", ticked);
#
#         simulation.force("link")
#                 .links(links);
#
#         // ms per tick
#         var intervl = setInterval(time_step, 100);
#         var time = mintime;
#
#         // simulates one time step
#         function time_step(){
#             //stop simulation
#             if(time == maxtime){
#                 clearInterval(intervl);
#             }
#
#             // get active links
#             active_links = [];
#             active_nodes = [];
#             if (edgesbytime[time]!=null)
#             {
#                 edgesbytime[time].forEach(function(id){
#                                 active_links.push( id );
#                                 node_ids = id.split('-');
#                                 active_nodes.push(node_ids[0]);
#                                 active_nodes.push(node_ids[1]);
#                         });
#             }
#
#             //color links based on activity
#             d3.selectAll('line').attr('class', 'tlinks');
#
#             active_links.forEach(function(l){
#                 d3.select('#'+l).attr('class', 'active');
#                 d3.select('#'+l).moveToFront();
#             });
#
#             // color nodes based on activity
#             d3.selectAll('circle').attr('class', 'tnodes');
#
#             active_nodes.forEach(function(n){
#                 d3.select('#'+n).attr('class', 'active');
#                 d3.select('#'+n).moveToFront();
#             });
#
#             // update time output
#             d3.select('text').html('time = ' + time);
#             time++;
#         }
#
#
#         function contains(array, obj) {
#             var i = array.length;
#             while (i--) {
#             if (array[i] === obj) {
#                 return true;
#             }
#             }
#             return false;
#         }
#
#
#         function dragstarted(d) {
#             if (!d3.event.active)
#                 simulation.alphaTarget(0.3).restart();
#             d.fx = d.x;
#             d.fy = d.y;
#         }
#
#         function dragged(d) {
#             d.fx = d3.event.x;
#             d.fy = d3.event.y;
#         }
#
#         function dragended(d) {
#             if (!d3.event.active)
#                 simulation.alphaTarget(0);
#             d.fx = null;
#             d.fy = null;
#         }
#
#         function ticked() {
#             // set position attributes
#             link
#                 .attr("x1", function(d) { return d.source.x; })
#                 .attr("y1", function(d) { return d.source.y; })
#                 .attr("x2", function(d) { return d.target.x; })
#                 .attr("y2", function(d) { return d.target.y; });
#
#             node
#                 .attr("cx", function(d) { return d.x; })
#                 .attr("cy", function(d) { return d.y; });
#         }
#         });
#     </script>
